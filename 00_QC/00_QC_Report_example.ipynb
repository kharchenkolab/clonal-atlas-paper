# %%
import subprocess
import sys
import time
import os

def lsAdameyko(path="/home/sergey/data/clonal_project/cellranger"):
    samples = subprocess.check_output(
        f'ssh -t sergey@adameykolab.srv.meduniwien.ac.at "ls {path}"', shell=True
    ).decode(sys.stdout.encoding).strip().split("\n")
    return samples

# %%
# Transfer of CellRanger outputs

samples = lsAdameyko("/home/sergey/data/clonal_project/cellranger")
for sample in ["Mb", "Mc"]:
    if not os.path.isdir(f"/home/sergey/data/clonal_project/cellranger/{sample}"):
        os.mkdir(f"/home/sergey/data/clonal_project/cellranger/{sample}")
    folders = lsAdameyko(f"/home/sergey/data/clonal_project/cellranger/{sample}")
    for folder in folders:
        time.sleep(0.5)
        os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/{folder}/outs/filtered_feature_bc_matrix.h5 /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_filtered_feature_bc_matrix.h5")
        os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/{folder}/outs/raw_feature_bc_matrix.h5 /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_raw_feature_bc_matrix.h5")
        os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/{folder}/outs/web_summary.html /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_web_summary.html")
        if folder == "GEX":
            os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/{folder}/velocyto/GEX.loom /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_velocyto.loom")
# Out:
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.

# %%
# Transfer of CellRanger outputs

samples = lsAdameyko("/home/sergey/data/clonal_project/cellranger")
for sample in samples:
    if not os.path.isdir(f"/home/sergey/data/clonal_project/cellranger/{sample}"):
        os.mkdir(f"/home/sergey/data/clonal_project/cellranger/{sample}")
    folders = lsAdameyko(f"/home/sergey/data/clonal_project/cellranger/{sample}")
    for folder in folders:
        time.sleep(0.5)
        if not os.path.exists(f"/home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_filtered_feature_bc_matrix.h5"):
            os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/{folder}/outs/filtered_feature_bc_matrix.h5 /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_filtered_feature_bc_matrix.h5")
            os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/{folder}/outs/raw_feature_bc_matrix.h5 /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_raw_feature_bc_matrix.h5")
            os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/{folder}/outs/web_summary.html /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_web_summary.html")
            if folder == "GEX":
                os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/{folder}/velocyto/GEX.loom /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_{folder}_velocyto.loom")
# Out:
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# scp: /home/sergey/data/clonal_project/cellranger/10x105/GEX_test/outs/filtered_feature_bc_matrix.h5: No such file or directory
# scp: /home/sergey/data/clonal_project/cellranger/10x105/GEX_test/outs/raw_feature_bc_matrix.h5: No such file or directory
# scp: /home/sergey/data/clonal_project/cellranger/10x105/GEX_test/outs/web_summary.html: No such file or directory
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# ...

# %%
# Transfer of CellRanger outputs

samples = lsAdameyko("/home/sergey/data/clonal_project/cellranger")
for sample in samples:
    if not os.path.isdir(f"/home/sergey/data/clonal_project/cellranger/{sample}"):
        os.mkdir(f"/home/sergey/data/clonal_project/cellranger/{sample}")
    folders = lsAdameyko(f"/home/sergey/data/clonal_project/cellranger/{sample}")
    if "GEX" in folders:
        folders = lsAdameyko(f"/home/sergey/data/clonal_project/cellranger/{sample}/GEX/outs")
        if "crispr_analysis" in folders:
            time.sleep(0.5)
            os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/GEX/outs/crispr_analysis/protospacer_calls_per_cell.csv /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_protospacer_calls_per_cell.csv")
            os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/cellranger/{sample}/GEX/outs/crispr_analysis/feature_reference.csv /home/sergey/data/clonal_project/cellranger/{sample}/{sample}_feature_reference.csv")
# Out:
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# ...

# %%
# Transfer of TREX output

samples = lsAdameyko("/home/sergey/data/clonal_project/trex")
for sample in samples:
    if not os.path.isdir(f"/home/sergey/data/clonal_project/trex/{sample}"):
        os.mkdir(f"/home/sergey/data/clonal_project/trex/{sample}")
    folders = lsAdameyko(f"/home/sergey/data/clonal_project/trex/{sample}")
    for folder in folders:
        time.sleep(0.5)
        os.system(f"scp sergey@adameykolab.srv.meduniwien.ac.at:/home/sergey/data/clonal_project/trex/{sample}/{folder}/umi_matrix.h5ad /home/sergey/data/clonal_project/trex/{sample}/{folder}.h5ad")
# Out:
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# ...

# %% [markdown]
# # Quality control
#
# For each dataset make a QC report:
# 1. UMI threshold (how many cells?);
# 2. number of doublets;
# 3. number of cells expressing a fluorescent protein;
# 4. number of cells with barcode;
# 5. distribution of clone size;
# 6. clusters without BC/FP.

# %%
import scanpy as sc
import numpy as np
import muon as mu
import scanpy.external as sce
import pandas as pd
import scvelo as scv
import seaborn as sns
import matplotlib.pyplot as plt
import importlib
import sys

# Figures aesthetics
sc.set_figure_params(dpi=150)

# Pathes
DATA_PATH = "/home/sergey/data/clonal_project"
HOME_PATH = "/home/sergey/projects/clonal_project"

# Additional functions
exec(open(f"{HOME_PATH}/tools/tools.py").read())
sns.set_style("ticks")

# %%
def log1pPF(adata):
    adata_tmp = adata.copy()
    adata_tmp.layers["counts"] = adata_tmp.X.copy()
    sc.pp.normalize_total(adata_tmp)
    sc.pp.log1p(adata_tmp)
    sc.pp.highly_variable_genes(adata_tmp, n_top_genes=3000)
    adata_tmp.layers["scaled"] = sc.pp.scale(adata_tmp.X, max_value=10, copy=True)
    adata_tmp.obsm["X_pca"] = sc.pp.pca(adata_tmp[:, adata_tmp.var.highly_variable].layers["scaled"])
    sc.pp.neighbors(adata_tmp, n_pcs=30, n_neighbors=20)
    sc.tl.umap(adata_tmp)
    sc.tl.leiden(adata_tmp)
    
    return adata_tmp

# %%
description = {
    "sample_id" : "Etoh_trunk",
    "batch" : "injection19",
    "FPs" : ["TOMbc"],
    "plasmids" : ["pMR671"],
    "location" : "trunk",
    "devtime" : "E13.5",
    "injections" : ["E8.5"],
    "CRISPR": False,
}

# %% [markdown]
# ## UMI QC

# %%
sample = description["sample_id"]

# GEX
adata = sc.read_10x_h5(f"{DATA_PATH}/cellranger/{sample}/{sample}_GEX_filtered_feature_bc_matrix.h5")
adata.obs.index = [sample + ":" + bc.split("-")[0] for bc in adata.obs.index]
adata.obs["batch"] = description["batch"]
adata.obs["sample_id"] = description["sample_id"]
adata.obs["location"] = description["location"]
adata.obs["devtime"] = description["devtime"]
adata.obs["plasmids"] = " + ".join(description["plasmids"])
adata.obs["injection"] = " + ".join(description["injections"])
    
# QC
adata.var["mt"] = adata.var_names.str.startswith("mt-")
sc.pp.calculate_qc_metrics(adata, inplace=True, percent_top=None, log1p=False, qc_vars=["mt"])
qc_plot = draw_counts_qc(adata, title=f"Sample {description['sample_id']}\n\nTotal number of cells before QC = {len(adata)}")
adata_prefiltered = adata.copy()

# %%
min_umi = 2000
min_genes = 2000
mt_max = 4

adata_tmp = adata.copy()
adata_tmp = adata_tmp[
    (adata_tmp.obs.total_counts >= min_umi) &
    (adata_tmp.obs.pct_counts_mt <= mt_max) &
    (adata_tmp.obs.n_genes_by_counts >= min_genes)
]

qc_plot = draw_counts_qc(adata_tmp, title=f"Total number of cells after QC = {len(adata_tmp)}")

# %%
adata = adata[adata_tmp.obs_names]

# %% [markdown]
# ## FPs

# %%
description["use_only_GEX"] = True

# %%
from scipy.sparse import vstack, hstack, csr_matrix

adatas_FP = {}
for FP in description["FPs"]:
    if description["use_only_GEX"]:
        adatas_FP[FP] = sc.read_h5ad(f"{DATA_PATH}/trex/{sample}/{FP}_GEX.h5ad")
    else:
        adatas_FP[FP] = sc.read_h5ad(f"{DATA_PATH}/trex/{sample}/{FP}.h5ad")
    adatas_FP[FP].obs.index = [sample + ":" + bc for bc in adatas_FP[FP].obs.index]
    adatas_FP[FP] = adatas_FP[FP][np.isin(adatas_FP[FP].obs_names, adata.obs_names)]
    empty_cells = adata.obs_names[~np.isin(adata.obs_names, adatas_FP[FP].obs_names)]
    adatas_FP[FP] = sc.AnnData(
        X=vstack([adatas_FP[FP].X, csr_matrix(np.zeros((len(empty_cells), len(adatas_FP[FP].var_names))))]),
        obs=pd.DataFrame(index=(list(adatas_FP[FP].obs_names) + list(empty_cells))),
        var=adatas_FP[FP].var
    )
    adatas_FP[FP] = adatas_FP[FP][adata.obs_names]
    adatas_FP[FP].X[(adatas_FP[FP].X <= 1).A] = 0
    adatas_FP[FP] = adatas_FP[FP][:, adatas_FP[FP].X.sum(axis=0).A[0] > 0]

# %%
if len(adatas_FP) == 2:
    adatas_FP_clear = resolve_confusion(adatas_FP)
    for FP in description["FPs"]:
        fig = draw_cloneID_QC(adatas_FP_clear[FP], FP)
else:
    fig = draw_cloneID_QC(adatas_FP[description["FPs"][0]], description["FPs"][0])

# %%
min_cloneID_umi = 2

if len(adatas_FP) == 2:
    FP1 = list(adatas_FP.keys())[0]
    FP2 = list(adatas_FP.keys())[1]

    FP1_clones = fast_clones(adatas_FP_clear[FP1], min_cloneID_umi=min_cloneID_umi)
    FP2_clones = fast_clones(adatas_FP_clear[FP2], min_cloneID_umi=min_cloneID_umi)
else:
    FP = list(adatas_FP.keys())[0]
    FP_clones = fast_clones(adatas_FP[FP], min_cloneID_umi=min_cloneID_umi)

# %% [markdown]
# ## CRISPR

# %%
if description["CRISPR"]:
    CRISPR = pd.read_csv(f"{DATA_PATH}/cellranger/{sample}/{sample}_protospacer_calls_per_cell.csv", index_col=0)
    CRISPR.index = [sample + ":" + bc.split("-")[0] for bc in CRISPR.index]

    gRNA_targets = {}
    CRISPR_reference = pd.read_csv(f"{DATA_PATH}/cellranger/{sample}/{sample}_feature_reference.csv", index_col=0)
    for gRNA, target in CRISPR_reference.iterrows():
        if ("NEG_CTRL-1" not in gRNA) and ("EGFP" not in gRNA):
            gene = target.target_gene_name
            gRNA_targets[gRNA] = gene[0] + gene[1:].lower()

    def transform_features(feature):
        return "|".join([gRNA_targets[i] if i in gRNA_targets else i for i in feature.split("|")])

    CRISPR["targets"] = [transform_features(feature) for feature in CRISPR.feature_call]

    not_in_index = adata.obs_names[~np.isin(adata.obs_names, CRISPR.index)]
    not_in_index = pd.DataFrame({
        "num_features": [0] * len(not_in_index),
        "feature_call": [np.nan] * len(not_in_index),
        "num_umis": [0] * len(not_in_index),
        "targets": [np.nan] * len(not_in_index),
    }, index=not_in_index)
    adata.obsm["CRISPR"] = pd.concat([CRISPR[np.isin(CRISPR.index, adata.obs_names)], not_in_index]).loc[adata.obs_names]

# %% [markdown]
# ## Report and saving

# %%
scrublet_threshold = 0.15
adata_final, adatas_FP_final = gex_qc_report(
    adata_prefiltered,
    adatas_FP,
    mt_name="mt-",
    mt_max=mt_max,
    savefig=f"QC_reports/{description['sample_id']}_GE.pdf",
    show=False,
    umi_min=min_umi,
    min_genes=min_genes,
    scrublet_threshold=scrublet_threshold,
    min_cloneID_umi=min_cloneID_umi,
)
# Out:
# WARNING: adata.X seems to be already log-transformed.
# WARNING: adata.X seems to be already log-transformed.

# %%
for FP in description["FPs"]:
    del adata_final.obs[f"cloneID_multiplet_{FP}"]
if len(description["FPs"]) == 2:
    del adata_final.obs[f"cloneID_multiplet"]
if description["CRISPR"]:
    adata_final.obsm["CRISPR"] = adata[adata_final.obs_names].obsm["CRISPR"]
del(
    adata_final.var["n_cells_by_counts"],
    adata_final.var["mean_counts"],
    adata_final.var["pct_dropout_by_counts"],
    adata_final.var["total_counts"]
)
adata_final.uns["QC"] = {
    "mt_max": mt_max,
    "min_umi": min_umi,
    "min_genes": min_genes,
    "scrublet_threshold": scrublet_threshold,
}

# %%
mdata = {"GEX": adata_final}
for FP in description["FPs"]:
    adatas_FP[FP].uns["QC"] = {"min_cloneID_umi": min_cloneID_umi}
    mdata[FP] = adatas_FP[FP]
mdata = mu.MuData(mdata)
mdata.update()
mdata.write_h5mu(f"{DATA_PATH}/anndatas_counts/{description['sample_id']}.h5mu")
